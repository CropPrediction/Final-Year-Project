# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("soilreq_updated.csv")

# %%
df.head()
# Out:
#        Village Texture                       Slope Slope_code  \
# 0  Hadonahalli     scl  Very gently sloping (1-3%)          B
# 1  Hadonahalli     scl  Very gently sloping (1-3%)          B
# 2  Hadonahalli      sl  Very gently sloping (1-3%)          B
# 3  Hadonahalli     scl       Gently sloping (3-5%)          C
# 4  Hadonahalli     scl  Very gently sloping (1-3%)          B
#
#             Erosion Erosion_code             Gravel Gravel_code  Rocky_leg  \
# 0    Slight erosion            A  Non gravel (<15%)           A  Non Rocky
# 1    Slight erosion            A  Non gravel (<15%)           A  Non Rocky
# 2    Slight erosion            A  Non gravel (<15%)           A  Non Rocky
# 3  Moderate erosion            B  Gravelly (15-35%)           B  Non Rocky
# 4    Slight erosion            A  Non gravel (<15%)           A  Non Rocky
#
#   Rocky_code                  Drinage Drinage_code                Depth  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 17 columns):
# Village         108 non-null object
# Texture         108 non-null object
# Slope           108 non-null object
# Slope_code      108 non-null object
# Erosion         108 non-null object
# Erosion_code    108 non-null object
# Gravel          108 non-null object
# Gravel_code     108 non-null object
# Rocky_leg       108 non-null object
# Rocky_code      108 non-null object
# Drinage         108 non-null object
# Drinage_code    108 non-null object
# Depth           108 non-null object
# Depth_code      108 non-null object
# LCC             108 non-null object
# Area            108 non-null float64
# obj_id          39 non-null float64
# dtypes: float64(2), object(15)
# memory usage: 14.4+ KB

# %%
df['Village'].unique()
# Out:
# array(['Hadonahalli', 'Durgennahalli', 'Thirumagaondanahalli'],
#       dtype=object)

# %%
df['Texture'].unique()
# Out:
# array(['scl', 'sl', 'ls', 'sc', 'Water body', 'Habitation', 'c',
#        'Forest plantation', 'Forest', 'Scrub land Open',
#        'Scrub land Dense', 'Rock out crop', 'Gullied land',
#        'Degraded land', 'Sandy'], dtype=object)

# %%
df['Slope'].unique()
# Out:
# array(['Very gently sloping (1-3%)', 'Gently sloping (3-5%)',
#        'Level to nearly level (0-1%)', 'Water body', 'Habitation',
#        'Moderately sloping (5-10%)', 'Forest plantation', 'Forest',
#        'Scrub land Open', 'Scrub land Dense', 'Rock out crop',
#        'Gullied land', 'Degraded land'], dtype=object)

# %%
df['Slope_code'].unique()
# Out:
# array(['B', 'C', 'A', 'Water body', 'Habitation', 'D',
#        'Forest plantation', 'Forest', 'Scrub land Open',
#        'Scrub land Dense', 'Rock out crop', 'Gullied land',
#        'Degraded land'], dtype=object)

# %%
df['Slope'].nunique()
# Out:
# 13

# %%
df['Slope_code'].nunique()
# Out:
# 13

# %%
hadonahalli=df[df['Village']=='Hadonahalli']

# %%
hadonahalli
# Out:
#         Village            Texture                         Slope  \
# 0   Hadonahalli                scl    Very gently sloping (1-3%)
# 1   Hadonahalli                scl    Very gently sloping (1-3%)
# 2   Hadonahalli                 sl    Very gently sloping (1-3%)
# 3   Hadonahalli                scl         Gently sloping (3-5%)
# 4   Hadonahalli                scl    Very gently sloping (1-3%)
# 5   Hadonahalli                 sl    Very gently sloping (1-3%)
# 6   Hadonahalli                scl    Very gently sloping (1-3%)
# 7   Hadonahalli                 ls  Level to nearly level (0-1%)
# 8   Hadonahalli                 sc    Very gently sloping (1-3%)
# 9   Hadonahalli         Water body                    Water body
# 10  Hadonahalli                 sc    Very gently sloping (1-3%)
# 11  Hadonahalli                 sl    Very gently sloping (1-3%)
# 12  Hadonahalli                scl    Very gently sloping (1-3%)
# ...

# %%
durgennahalli=df[df['Village']=="Durgennahalli"]

# %%
durgennahalli
# Out:
#           Village          Texture                       Slope  \
# 69  Durgennahalli    Rock out crop               Rock out crop
# 70  Durgennahalli               sl       Gently sloping (3-5%)
# 71  Durgennahalli               ls  Very gently sloping (1-3%)
# 72  Durgennahalli  Scrub land Open             Scrub land Open
# 73  Durgennahalli    Rock out crop               Rock out crop
# 74  Durgennahalli  Scrub land Open             Scrub land Open
# 75  Durgennahalli     Gullied land                Gullied land
# 76  Durgennahalli     Gullied land                Gullied land
# 77  Durgennahalli              scl  Very gently sloping (1-3%)
# 78  Durgennahalli  Scrub land Open             Scrub land Open
# 79  Durgennahalli              scl  Very gently sloping (1-3%)
# 80  Durgennahalli              scl  Very gently sloping (1-3%)
# 81  Durgennahalli              scl  Very gently sloping (1-3%)
# 82  Durgennahalli               sl       Gently sloping (3-5%)
# ...

# %%
len(durgennahalli)
# Out:
# 29

# %%
thirumagaondanahalli=df[df['Village']=='Thirumagaondanahalli']

# %%
thirumagaondanahalli
# Out:
#                   Village     Texture       Slope  Slope_code     Erosion  \
# 98   Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 99   Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 100  Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 101  Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 102  Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 103  Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 104  Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 105  Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 106  Thirumagaondanahalli  Water body  Water body  Water body  Water body
# 107  Thirumagaondanahalli  Water body  Water body  Water body  Water body
#
#     Erosion_code      Gravel Gravel_code   Rocky_leg  Rocky_code     Drinage  \
# ...

# %%
len(thirumagaondanahalli)
# Out:
# 10

# %%
hadonahalli
# Out:
#         Village            Texture                         Slope  \
# 0   Hadonahalli                scl    Very gently sloping (1-3%)
# 1   Hadonahalli                scl    Very gently sloping (1-3%)
# 2   Hadonahalli                 sl    Very gently sloping (1-3%)
# 3   Hadonahalli                scl         Gently sloping (3-5%)
# 4   Hadonahalli                scl    Very gently sloping (1-3%)
# 5   Hadonahalli                 sl    Very gently sloping (1-3%)
# 6   Hadonahalli                scl    Very gently sloping (1-3%)
# 7   Hadonahalli                 ls  Level to nearly level (0-1%)
# 8   Hadonahalli                 sc    Very gently sloping (1-3%)
# 9   Hadonahalli         Water body                    Water body
# 10  Hadonahalli                 sc    Very gently sloping (1-3%)
# 11  Hadonahalli                 sl    Very gently sloping (1-3%)
# 12  Hadonahalli                scl    Very gently sloping (1-3%)
# ...

# %%
hadonahalli['Texture'].unique()
# Out:
# array(['scl', 'sl', 'ls', 'sc', 'Water body', 'Habitation', 'c',
#        'Forest plantation', 'Forest', 'Scrub land Open',
#        'Scrub land Dense'], dtype=object)

# %%
hadonahalli['Texture'].nunique()
# Out:
# 11

# %%
hadonahalli['Slope'].unique()
# Out:
# array(['Very gently sloping (1-3%)', 'Gently sloping (3-5%)',
#        'Level to nearly level (0-1%)', 'Water body', 'Habitation',
#        'Moderately sloping (5-10%)', 'Forest plantation', 'Forest',
#        'Scrub land Open', 'Scrub land Dense'], dtype=object)

# %%
li=['Water body','Forest','Habitation','Forest plantation','Scrub land Open','Scrub land Dense']

# %%
hadon=hadonahalli[~hadonahalli['Texture'].isin(li)]

# %%
hadon
# Out:
#         Village Texture                         Slope Slope_code  \
# 0   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 1   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 2   Hadonahalli      sl    Very gently sloping (1-3%)          B
# 3   Hadonahalli     scl         Gently sloping (3-5%)          C
# 4   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 5   Hadonahalli      sl    Very gently sloping (1-3%)          B
# 6   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 7   Hadonahalli      ls  Level to nearly level (0-1%)          A
# 8   Hadonahalli      sc    Very gently sloping (1-3%)          B
# 10  Hadonahalli      sc    Very gently sloping (1-3%)          B
# 11  Hadonahalli      sl    Very gently sloping (1-3%)          B
# 12  Hadonahalli     scl    Very gently sloping (1-3%)          B
# 13  Hadonahalli      ls    Very gently sloping (1-3%)          B
# ...

# %%
len(hadon)
# Out:
# 49

# %%
hadon['Texture'].unique()
# Out:
# array(['scl', 'sl', 'ls', 'sc', 'c'], dtype=object)

# %%
hadon['Slope'].unique()
# Out:
# array(['Very gently sloping (1-3%)', 'Gently sloping (3-5%)',
#        'Level to nearly level (0-1%)', 'Moderately sloping (5-10%)'],
#       dtype=object)

# %%
hadon['Slope_code'].unique()
# Out:
# array(['B', 'C', 'A', 'D'], dtype=object)

# %%
type(hadon)
# Out:
# pandas.core.frame.DataFrame

# %%
final=hadon[['Village','Slope_code']]

# %%
final
# Out:
#         Village Slope_code
# 0   Hadonahalli          B
# 1   Hadonahalli          B
# 2   Hadonahalli          B
# 3   Hadonahalli          C
# 4   Hadonahalli          B
# 5   Hadonahalli          B
# 6   Hadonahalli          B
# 7   Hadonahalli          A
# 8   Hadonahalli          B
# 10  Hadonahalli          B
# 11  Hadonahalli          B
# 12  Hadonahalli          B
# 13  Hadonahalli          B
# 14  Hadonahalli          C
# 15  Hadonahalli          B
# 16  Hadonahalli          C
# 18  Hadonahalli          C
# 19  Hadonahalli          C
# 20  Hadonahalli          C
# 21  Hadonahalli          D
# 22  Hadonahalli          C
# 23  Hadonahalli          B
# 24  Hadonahalli          B
# 25  Hadonahalli          B
# 26  Hadonahalli          A
# 27  Hadonahalli          C
# 28  Hadonahalli          D
# 29  Hadonahalli          B
# 30  Hadonahalli          A
# 31  Hadonahalli          C
# 32  Hadonahalli          B
# 33  Hadonahalli          B
# 34  Hadonahalli          B
# ...

# %%
hadon['Erosion'].unique()
# Out:
# array(['Slight erosion', 'Moderate erosion', 'Severe erosion'],
#       dtype=object)

# %%
hadon['Erosion_code'].unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
hadon['Gravel'].unique()
# Out:
# array(['Non gravel (<15%)', 'Gravelly (15-35%)'], dtype=object)

# %%
hadon['Gravel_code'].unique()
# Out:
# array(['A', 'B'], dtype=object)

# %%
hadon['Rocky_leg'].unique()
# Out:
# array(['Non Rocky', 'Rocky (2-10%)', 'Extremly rocky (25-50%)',
#        'Very rocky (10-25%)'], dtype=object)

# %%
hadon['Rocky_code'].unique()
# Out:
# array(['A', 'B', 'C', 'R2'], dtype=object)

# %%
hadon['Drinage_code'].unique()
# Out:
# array(['A'], dtype=object)

# %%
hadon['Drinage'].unique()
# Out:
# array(['Well drained', 'Moderately well drained'], dtype=object)

# %%
hadon['Drainage_code'] = ['A' if x =='Well drained' else 'B' for x in hadon['Drinage']]
# Out:
# C:\Users\lavan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hadon
# Out:
#         Village Texture                         Slope Slope_code  \
# 0   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 1   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 2   Hadonahalli      sl    Very gently sloping (1-3%)          B
# 3   Hadonahalli     scl         Gently sloping (3-5%)          C
# 4   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 5   Hadonahalli      sl    Very gently sloping (1-3%)          B
# 6   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 7   Hadonahalli      ls  Level to nearly level (0-1%)          A
# 8   Hadonahalli      sc    Very gently sloping (1-3%)          B
# 10  Hadonahalli      sc    Very gently sloping (1-3%)          B
# 11  Hadonahalli      sl    Very gently sloping (1-3%)          B
# 12  Hadonahalli     scl    Very gently sloping (1-3%)          B
# 13  Hadonahalli      ls    Very gently sloping (1-3%)          B
# ...

# %%
a=hadon['Drainage_code']

# %%
final=final.join(a)

# %%
a=hadon['Texture']

# %%
final=final.join(a)

# %%
a=hadon['Erosion_code']

# %%
final=final.join(a)

# %%
final
# Out:
#         Village Slope_code Drainage_code Texture Erosion_code
# 0   Hadonahalli          B             A     scl            A
# 1   Hadonahalli          B             A     scl            A
# 2   Hadonahalli          B             A      sl            A
# 3   Hadonahalli          C             A     scl            B
# 4   Hadonahalli          B             B     scl            A
# 5   Hadonahalli          B             B      sl            A
# 6   Hadonahalli          B             B     scl            A
# 7   Hadonahalli          A             A      ls            A
# 8   Hadonahalli          B             B      sc            A
# 10  Hadonahalli          B             B      sc            A
# 11  Hadonahalli          B             A      sl            A
# 12  Hadonahalli          B             A     scl            A
# 13  Hadonahalli          B             A      ls            A
# 14  Hadonahalli          C             A      sl            B
# ...

# %%
a=hadon['Gravel_code']

# %%
final=final.join(a)

# %%
a=hadon['Rocky_code']

# %%
final=final.join(a)

# %%
hadon['Depth'].unique()
# Out:
# array(['Very deep (>150 cm)', 'Deep (100-150 cm)', 'Shallow (25-50 cm)'],
#       dtype=object)

# %%
hadon['Depth_code'].unique()
# Out:
# array(['A', 'B', 'Shallow (25-50 cm)'], dtype=object)

# %%
filter1 = hadon['Depth']
for x in filter1:
    if x =='Shallow (25-50 cm)':
        hadon['Depth_code'] = hadon['Depth_code'].replace('Shallow (25-50 cm)', 'C')
# Out:
# C:\Users\lavan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
hadon
# Out:
#         Village Texture                         Slope Slope_code  \
# 0   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 1   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 2   Hadonahalli      sl    Very gently sloping (1-3%)          B
# 3   Hadonahalli     scl         Gently sloping (3-5%)          C
# 4   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 5   Hadonahalli      sl    Very gently sloping (1-3%)          B
# 6   Hadonahalli     scl    Very gently sloping (1-3%)          B
# 7   Hadonahalli      ls  Level to nearly level (0-1%)          A
# 8   Hadonahalli      sc    Very gently sloping (1-3%)          B
# 10  Hadonahalli      sc    Very gently sloping (1-3%)          B
# 11  Hadonahalli      sl    Very gently sloping (1-3%)          B
# 12  Hadonahalli     scl    Very gently sloping (1-3%)          B
# 13  Hadonahalli      ls    Very gently sloping (1-3%)          B
# ...

# %%
a=hadon['Depth_code']

# %%
final=final.join(a)

# %%
hadon['LCC'].unique()
# Out:
# array(['I', 'II', 'III'], dtype=object)

# %%
final=final.join(hadon['LCC'])

# %%
final
# Out:
#         Village Slope_code Drainage_code Texture Erosion_code Gravel_code  \
# 0   Hadonahalli          B             A     scl            A           A
# 1   Hadonahalli          B             A     scl            A           A
# 2   Hadonahalli          B             A      sl            A           A
# 3   Hadonahalli          C             A     scl            B           B
# 4   Hadonahalli          B             B     scl            A           A
# 5   Hadonahalli          B             B      sl            A           A
# 6   Hadonahalli          B             B     scl            A           A
# 7   Hadonahalli          A             A      ls            A           A
# 8   Hadonahalli          B             B      sc            A           A
# 10  Hadonahalli          B             B      sc            A           A
# 11  Hadonahalli          B             A      sl            A           A
# 12  Hadonahalli          B             A     scl            A           A
# ...

# %%
type(hadon['Area'])
# Out:
# pandas.core.series.Series

# %%
final=final.join(hadon['Area'])

# %%
final
# Out:
#         Village Slope_code Drainage_code Texture Erosion_code Gravel_code  \
# 0   Hadonahalli          B             A     scl            A           A
# 1   Hadonahalli          B             A     scl            A           A
# 2   Hadonahalli          B             A      sl            A           A
# 3   Hadonahalli          C             A     scl            B           B
# 4   Hadonahalli          B             B     scl            A           A
# 5   Hadonahalli          B             B      sl            A           A
# 6   Hadonahalli          B             B     scl            A           A
# 7   Hadonahalli          A             A      ls            A           A
# 8   Hadonahalli          B             B      sc            A           A
# 10  Hadonahalli          B             B      sc            A           A
# 11  Hadonahalli          B             A      sl            A           A
# 12  Hadonahalli          B             A     scl            A           A
# ...

# %%
final['Area']=final['Area'].astype('float')

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 68
# Data columns (total 10 columns):
# Village          49 non-null object
# Slope_code       49 non-null object
# Drainage_code    49 non-null object
# Texture          49 non-null object
# Erosion_code     49 non-null object
# Gravel_code      49 non-null object
# Rocky_code       49 non-null object
# Depth_code       49 non-null object
# LCC              49 non-null object
# Area             49 non-null float64
# dtypes: float64(1), object(9)
# memory usage: 5.5+ KB

# %%
final
# Out:
#         Village Slope_code Drainage_code Texture Erosion_code Gravel_code  \
# 0   Hadonahalli          B             A     scl            A           A
# 1   Hadonahalli          B             A     scl            A           A
# 2   Hadonahalli          B             A      sl            A           A
# 3   Hadonahalli          C             A     scl            B           B
# 4   Hadonahalli          B             B     scl            A           A
# 5   Hadonahalli          B             B      sl            A           A
# 6   Hadonahalli          B             B     scl            A           A
# 7   Hadonahalli          A             A      ls            A           A
# 8   Hadonahalli          B             B      sc            A           A
# 10  Hadonahalli          B             B      sc            A           A
# 11  Hadonahalli          B             A      sl            A           A
# 12  Hadonahalli          B             A     scl            A           A
# ...

# %%
final.to_excel('hadonahalli.xlsx')
